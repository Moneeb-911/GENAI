# %%
# !pip install accelerate transformers einops langchain bitsandbytes huggingface_hub

# %%
import getpass
from huggingface_hub import login

# Prompt for the Hugging Face token
hf_token = getpass.getpass("Enter your Hugging Face token: ")

# Login using the token
login(token=hf_token)
# Out:
# Enter your Hugging Face token:  ········
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM
# Set local_files_only=False to allow downloading the model
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B", local_files_only=False)
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B", local_files_only=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
from transformers import pipeline
text_generation_pipeline = pipeline("text-generation", model=model, tokenizer=tokenizer)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
text_generation_pipeline("what is python and why it is used",max_new_tokens=100,num_return_sequences=1,)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [{'generated_text': 'what is python and why it is used in the field of data science?\nPython is an open-source programming language that has been widely used in the field of data science. It is known for its simplicity, readability, and scalability. Python is also a general-purpose programming language that can be used for a variety of tasks, including data analysis, machine learning, and web development.\nPython is a high-level, interpreted, and object-oriented programming language. It is known for its simplicity and readability, making it an ideal language for data scientists. Python'}]
